# %%
### 데이터 프레임 생성 문제1 : df1 생성
# - 데이터 : numpy 패키지의 randn 함수를 이용해서 난수 n 개 생성
# - 행방향 인덱스(index) : 날짜 데이터
# - 열방향 인덱스(column) : ['A','B','C','D']
# Out:
#                    A         B         C         D
# 2021-07-01 -0.920524  1.105321  1.329705 -0.000770
# 2021-07-02  0.749611  0.074379 -0.679484 -0.618341
# 2021-07-03  1.180212 -0.669366  0.794012 -0.029445

# %%
import warnings
# 경고메세지 끄기
warnings.filterwarnings(action='ignore')

# 다시 출력하게 하기
# warnings.filterwarnings(action='default')

# %%
# 필요 패키지 import
import pandas as pd
import numpy as np
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity="all"

# %%
#2019년 1월1일 이후 일요일 날짜 6개를 생성하여 저장하시오
dates = pd.date_range(start = '2019-01-01',periods=6,freq = 'w') 
dates
# Out:
# DatetimeIndex(['2019-01-06', '2019-01-13', '2019-01-20', '2019-01-27',
#                '2019-02-03', '2019-02-10'],
#               dtype='datetime64[ns]', freq='W-SUN')

# %%
#아래와 같은 DataFrame을 생성 하시오
rand = np.random.randn(24)
rand.reshape(6,4)
df1=pd.DataFrame(rand.reshape(6,4),index = dates, columns = ['A','B','C','D'])
df1
# Out:
#                    A         B         C         D
# 2019-01-06 -0.750578 -0.913083 -0.489999 -1.132089
# 2019-01-13  1.029136  0.876578  0.139968 -0.502628
# 2019-01-20 -0.563116  1.957525 -0.272698 -1.104916
# 2019-01-27  1.969547 -0.353090 -1.046400 -0.548723
# 2019-02-03 -1.149064 -0.339216 -0.421717  1.441064
# 2019-02-10  0.083146 -1.832960 -1.769765  1.024766

# %%
# 예제 df4 생성
data = [[22, 60.1, 170.5, '남', '서울'], 
        [45, 51.3, 157.3, '여', '부산'], 
        [22, 68.3, 180.1, '남', '대구'],
        [33, 88.3, 190.2, '남', '제주'], 
        [27, 48.3, 160.1, '여', '강릉']]
df4 = pd.DataFrame(data, index=['홍길동', '이몽룡', '성춘향','변학도', '김연아'], 
                   columns=["나이", "몸무게", "키", "성별" ,"주소"])
df4
# Out:
#      나이   몸무게      키 성별  주소
# 홍길동  22  60.1  170.5  남  서울
# 이몽룡  45  51.3  157.3  여  부산
# 성춘향  22  68.3  180.1  남  대구
# 변학도  33  88.3  190.2  남  제주
# 김연아  27  48.3  160.1  여  강릉

# %% [markdown]
# ##### 데이터프레임 전치 문제
# - df4 데이터프레임을 전치 후에 df4_1로 저장하고 원본과 비교 출력 하시오.

# %%
df4_1 = df4.T

# %%
df4_1
df4
# Out:
#        홍길동    이몽룡    성춘향    변학도    김연아
# 나이      22     45     22     33     27
# 몸무게   60.1   51.3   68.3   88.3   48.3
# 키    170.5  157.3  180.1  190.2  160.1
# 성별       남      여      남      남      여
# 주소      서울     부산     대구     제주     강릉
#      나이   몸무게      키 성별  주소
# 홍길동  22  60.1  170.5  남  서울
# 이몽룡  45  51.3  157.3  여  부산
# 성춘향  22  68.3  180.1  남  대구
# 변학도  33  88.3  190.2  남  제주
# 김연아  27  48.3  160.1  여  강릉

# %% [markdown]
# #### 인덱싱 문제
# - 다음 데이터프레임에서 지정하는 데이터를 뽑아내거나  처리하라.

# %%
data = {
    "국어": [80, 90, 70, 30],
    "영어": [90, 70, 60, 40],
    "수학": [90, 60, 80, 70]
}

columns = ["국어", "영어", "수학"]
index = ["춘향", "몽룡", "향단", "방자"]

df = pd.DataFrame(data, index=index, columns=columns)

#문1.  모든 학생의 수학 점수를 시리즈로 나타낸다.
#문2.  모든 학생의 국어와 영어 점수를 데이터 프레임으로 나타낸다.
#문3.  모든 학생의 각 과목 평균 점수를 새로운 열로 추가한다.
#문4.  방자의 영어 점수를 80점으로 수정하고 평균 점수도 다시 계산한다.
#문5.  춘향의 점수를 데이터프레임으로 나타낸다.
#문6.  향단의 점수를 시리즈로 나타낸다.

# %%
df
# Out:
#     국어  영어  수학
# 춘향  80  90  90
# 몽룡  90  70  60
# 향단  70  60  80
# 방자  30  40  70

# %%
# 모든 학생의 수학 점수를 시리즈로 나타낸다.
a =df['수학']
print(a,type(a))
# Out:
# 춘향    90
# 몽룡    60
# 향단    80
# 방자    70
# Name: 수학, dtype: int64 <class 'pandas.core.series.Series'>

# %%
# 모든 학생의 국어와 영어 점수를 데이터 프레임으로 나타낸다.
df[['국어','영어']]
# Out:
#     국어  영어
# 춘향  80  90
# 몽룡  90  70
# 향단  70  60
# 방자  30  40

# %%
# 모든 학생의 각 과목 평균 점수를 새로운 열로 추가한다.

df['평균점수']=df.T.mean()
df
# Out:
#     국어  영어  수학  평균점수
# 춘향  80  90  90 86.67
# 몽룡  90  70  60 73.33
# 향단  70  60  80 70.00
# 방자  30  40  70 46.67

# %%
#pandas 출력 포맷팅 : 소수점이하 2자리
pd.options.display.float_format = '{:.2f}'.format
df
# Out:
#     국어  영어  수학  평균점수
# 춘향  80  90  90 86.67
# 몽룡  90  70  60 73.33
# 향단  70  60  80 70.00
# 방자  30  80  70 46.67

# %%
#정한 표기법을 원래 상태로 복귀 : None를 지정
pd.set_option('display.float_format',None)
df
# Out:
#     국어  영어  수학       평균점수
# 춘향  80  90  90  86.666667
# 몽룡  90  70  60  73.333333
# 향단  70  60  80  70.000000
# 방자  30  80  70  46.666667

# %%
# 방자의 영어 점수를 80점으로 수정하고 평균 점수도 
# 다시 계산한다.
df['영어']['방자']=80
df['평균점수']=df.T.mean()
df
# Out:
#     국어  영어  수학  평균점수
# 춘향  80  90  90 86.67
# 몽룡  90  70  60 73.33
# 향단  70  60  80 70.00
# 방자  30  80  70 56.67

# %%
# 춘향의 점수를 데이터프레임으로 나타낸다.
df[0:1]


# 몽룡의 점수를 데이터 프레임으로 나타내는 경우
df[1:2]
# Out:
#     국어  영어  수학  평균점수
# 춘향  80  90  90 86.67
#     국어  영어  수학  평균점수
# 몽룡  90  70  60 73.33

# %%
#향단의 점수 시리즈로
#시리즈는 열방향 데이터일 경우에 추출 가능
df.T['향단']
# Out:
# 국어     70.00
# 영어     60.00
# 수학     80.00
# 평균점수   70.00
# Name: 향단, dtype: float64
